# %% [markdown]
# <a href="https://colab.research.google.com/github/dalandanshek/cs1-python-diamond-salcedo/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world from Daniella!")
# Out:
# Hello world from Daniella!
